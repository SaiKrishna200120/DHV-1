# %% [markdown]
# # Visualization of obesity data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %% [markdown]
# Creating new column called BMI

# %%
df['BMI']=df['Weight']/df['Height']**2

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE          BMI
# count  2111.000000  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866    29.700159
# std       0.612953     0.850592     0.608927     8.011337
# min       1.000000     0.000000     0.000000    12.998685
# ...

# %% [markdown]
# Grouping the data

# %%
data =df.groupby('Age')
groupage = data.mean('Age')
groupage=groupage.reset_index()
groupage
# Out:
#             Age    Height     Weight      FCVC       NCP      CH2O       FAF  \
# 0     14.000000  1.710000  72.000000  3.000000  3.000000  3.000000  2.000000
# 1     15.000000  1.650000  86.000000  3.000000  3.000000  1.000000  3.000000
# 2     16.000000  1.664444  55.333333  2.111111  2.222222  1.888889  1.111111
# 3     16.093234  1.608914  65.000000  1.321028  1.000000  2.000000  0.371452
# 4     16.129279  1.650000  85.583485  2.954996  3.000000  1.000000  2.091862
# ...         ...       ...        ...       ...       ...       ...       ...
# 1397  55.022494  1.673394  80.400306  2.000000  3.000000  2.000000  1.000000
# 1398  55.137881  1.657221  80.993213  2.000000  3.000000  2.000000  1.000000
# 1399  55.246250  1.769269  80.491339  2.000000  3.000000  2.000000  1.000000
# 1400  56.000000  1.790000  90.000000  2.000000  3.000000  2.000000  1.000000
# 1401  61.000000  1.650000  66.000000  3.000000  3.000000  2.000000  1.000000
#
#            TUE        BMI
# ...

# %%
data1 = df.groupby('Gender')
groupgen = data1.mean('Gender')
groupgen = groupgen.reset_index()

# %%
sns.barplot(x='Gender',y='CH2O',data=groupgen)
plt.yscale('log')

# %%
sns.barplot(x='Gender',y='FCVC',data=groupgen)
plt.yscale('log')

# %%
sns.scatterplot(x='Age',y='BMI',data =groupage,hue=df['Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
sns.scatterplot(x='Age',y='Height',data =groupage,hue=df['Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.scatterplot(x='Age',y='Weight',data =groupage,hue=df['Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
 sns.lmplot(x='Age', y='BMI', hue='Gender', data=df, fit_reg=True)
# Out:
# C:\Users\ajays\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
 sns.lmplot(x='Age', y='Height', hue='Gender', data=df, fit_reg=True)
# Out:
# C:\Users\ajays\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
 sns.lmplot(x='Age', y='Weight', hue='Gender', data=df, fit_reg=True)
# Out:
# C:\Users\ajays\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(x='Age',data=df,bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Height',data=df,bins=10)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.histplot(x='Weight',data=df,bins=10)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
sns.histplot(x='BMI',data=df,bins=10)
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
sns.heatmap(df[['Age','Height','Weight','FCVC','NCP','CH2O','FAF','TUE','BMI']].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
plt.grid()
plt.yscale('log')
